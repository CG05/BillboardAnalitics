# %%
import billboard
from pprint import pprint

chart = billboard.ChartData('hot-100')
top20 = chart[:20]

# %%
titles = [{"info":[song.title, song.artist], "label": song.rank} for song in top20]
pprint(titles)
# Out:
# [{'info': ['Not Like Us', 'Kendrick Lamar'], 'label': 1},
#  {'info': ['A Bar Song (Tipsy)', 'Shaboozey'], 'label': 2},
#  {'info': ['I Had Some Help', 'Post Malone Featuring Morgan Wallen'],
#   'label': 3},
#  {'info': ['Million Dollar Baby', 'Tommy Richman'], 'label': 4},
#  {'info': ['Espresso', 'Sabrina Carpenter'], 'label': 5},
#  {'info': ['Please Please Please', 'Sabrina Carpenter'], 'label': 6},
#  {'info': ['Lies Lies Lies', 'Morgan Wallen'], 'label': 7},
#  {'info': ['Too Sweet', 'Hozier'], 'label': 8},
#  {'info': ['Beautiful Things', 'Benson Boone'], 'label': 9},
#  {'info': ['Lose Control', 'Teddy Swims'], 'label': 10},
#  {'info': ['Birds Of A Feather', 'Billie Eilish'], 'label': 11},
#  {'info': ['Pink Skies', 'Zach Bryan'], 'label': 12},
#  {'info': ['Good Luck, Babe!', 'Chappell Roan'], 'label': 13},
#  {'info': ['28', 'Zach Bryan'], 'label': 14},
#  {'info': ['Cowgirls', 'Morgan Wallen Featuring ERNEST'], 'label': 15},
#  {'info': ['Fortnight', 'Taylor Swift Featuring Post Malone'], 'label': 16},
#  {'info': ['Like That', 'Future, Metro Boomin & Kendrick Lamar'], 'label': 17},
#  {'info': ['Houdini', 'Eminem'], 'label': 18},
#  {'info': ['Saturn', 'SZA'], 'label': 19},
#  {'info': ['Miles On It', 'Marshmello & Kane Brown'], 'label': 20}]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import pandas as pd

cid = "8494dc579e694b9a91d1728fe3be9b96"
secret = "d571c3a3139849a68734f206590794fa"
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
track = sp.search("Not Like Us - Kendrick Lamar", limit=1)
pprint(track)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Not+Like+Us+-+Kendrick+Lamar&type=track&offset=0&limit=1',
#             'items': [{'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#                                               'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#                                               'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#                                               'name': 'Kendrick Lamar',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#                                  'href': 'https://api.spotify.com/v1/albums/5JjnoGJyOxfSZUZtk2rRwZ',
#                                  'id': '5JjnoGJyOxfSZUZtk2rRwZ',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731ea0c62b2339cbf493a999ad',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021ea0c62b2339cbf493a999ad',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511ea0c62b2339cbf493a999ad',
#                                              'width': 64}],
#                                  'name': 'Not Like Us',
#                                  'release_date': '2024-05-04',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:5JjnoGJyOxfSZUZtk2rRwZ'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#                                     'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#                                     'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#                                     'name': 'Kendrick Lamar',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 274192,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USUG12400910'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6AI3ezQ4o3HUoP6Dhudph3'},
#                        'href': 'https://api.spotify.com/v1/tracks/6AI3ezQ4o3HUoP6Dhudph3',
#                        'id': '6AI3ezQ4o3HUoP6Dhudph3',
#                        'is_local': False,
#                        'name': 'Not Like Us',
#                        'popularity': 97,
#                        'preview_url': None,
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:6AI3ezQ4o3HUoP6Dhudph3'}],
#             'limit': 1,
#             'next': 'https://api.spotify.com/v1/search?query=Not+Like+Us+-+Kendrick+Lamar&type=track&offset=1&limit=1',
#             'offset': 0,
#             'previous': None,
#             'total': 812}}

# %%
feature = sp.audio_features(tracks=[track['tracks']['items'][0]['id']])
pprint(feature)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:934, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     933 try:
# --> 934     retries = retries.increment(method, url, response=response, _pool=self)
#     935 except MaxRetryError:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=6AI3ezQ4o3HUoP6Dhudph3 (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\adapters.py:691, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     690 if isinstance(e.reason, ResponseError):
# --> 691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=6AI3ezQ4o3HUoP6Dhudph3 (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 feature = sp.audio_features(tracks=[track['tracks']['items'][0]['id']])
#       2 pprint(feature)
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:1753, in Spotify.audio_features(self, tracks)
#    1751 else:
#    1752     tlist = [self._get_id("track", t) for t in tracks]
# -> 1753     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1754 # the response has changed, look for the new style first, and if
#    1755 # it's not there, fallback on the old style
#    1756 if "audio_features" in results:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:311, in Spotify._internal_call(self, method, url, payload, params)
#     309     except (IndexError, AttributeError):
#     310         reason = None
# --> 311     raise SpotifyException(
#     312         429,
#     313         -1,
#     314         f"{request.path_url}:\n Max Retries",
#     315         reason=reason
#     316     )
#     317 except ValueError:
#     318     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=6AI3ezQ4o3HUoP6Dhudph3:
#  Max Retries, reason: too many 429 error responses

# %%
from datetime import datetime, timedelta
curdate = datetime.now()

yearchartarr = []
curday = datetime(2022, 1, 1)
while (curday.year == 2022):
    dayformat = curday.strftime('%Y-%m-%d')
    charts = billboard.ChartData('hot-100', date=dayformat)
    curday += timedelta(weeks=1)
    dayarr = []
    for song in charts:
        arr = [dayformat, song.title, song.artist, song.rank, []]
        dayarr.append(arr)
    yearchartarr.append(dayarr)

# %%
yearchart = np.array(yearchartarr, dtype=object)
pprint(yearchart)
yearchart.shape
# Out:
# array([[['2022-01-01', 'All I Want For Christmas Is You',
#          'Mariah Carey', 1, list([])],
#         ['2022-01-01', "Rockin' Around The Christmas Tree",
#          'Brenda Lee', 2, list([])],
#         ['2022-01-01', 'Jingle Bell Rock', 'Bobby Helms', 3, list([])],
#         ...,
#         ['2022-01-01', 'No Love', 'Summer Walker & SZA', 98, list([])],
#         ['2022-01-01', 'Knowing You', 'Kenny Chesney', 99, list([])],
#         ['2022-01-01', 'Family Ties', 'Baby Keem & Kendrick Lamar', 100,
#          list([])]],
#
#        [['2022-01-08', 'All I Want For Christmas Is You',
#          'Mariah Carey', 1, list([])],
#         ['2022-01-08', 'Easy On Me', 'Adele', 2, list([])],
#         ['2022-01-08', "Rockin' Around The Christmas Tree",
#          'Brenda Lee', 3, list([])],
#         ...,
#         ['2022-01-08', 'No Love', 'Summer Walker & SZA', 98, list([])],
#         ['2022-01-08', '23', 'Sam Hunt', 99, list([])],
#         ['2022-01-08', 'Family Ties', 'Baby Keem & Kendrick Lamar', 100,
#          list([])]],
#
#        [['2022-01-15', 'Easy On Me', 'Adele', 1, list([])],
#         ['2022-01-15', 'Stay', 'The Kid LAROI & Justin Bieber', 2,
#          list([])],
#         ['2022-01-15', 'Heat Waves', 'Glass Animals', 3, list([])],
#         ...,
#         ['2022-01-15', 'Bad Man (Smooth Criminal)', 'Polo G', 98,
#          list([])],
#         ['2022-01-15', 'Never Wanted To Be That Girl',
#          'Carly Pearce & Ashley McBryde', 99, list([])],
#         ['2022-01-15', 'Just About Over You', 'Priscilla Block', 100,
#          list([])]],
#
#        ...,
#
#        [['2022-12-17', 'All I Want For Christmas Is You',
#          'Mariah Carey', 1, list([])],
#         ['2022-12-17', "Rockin' Around The Christmas Tree",
#          'Brenda Lee', 2, list([])],
#         ['2022-12-17', 'Jingle Bell Rock', 'Bobby Helms', 3, list([])],
#         ...,
#         ['2022-12-17', 'Blue Christmas', 'Kane Brown', 98, list([])],
#         ['2022-12-17', 'Freestyle', 'Lil Baby', 99, list([])],
#         ['2022-12-17', 'Escapism', 'RAYE Featuring 070 Shake', 100,
#          list([])]],
#
#        [['2022-12-24', 'All I Want For Christmas Is You',
#          'Mariah Carey', 1, list([])],
#         ['2022-12-24', "Rockin' Around The Christmas Tree",
#          'Brenda Lee', 2, list([])],
#         ['2022-12-24', 'Kill Bill', 'SZA', 3, list([])],
#         ...,
#         ['2022-12-24', 'Around Me',
#          'Metro Boomin Featuring Don Toliver', 98, list([])],
#         ['2022-12-24', 'Tennessee Fan', 'Morgan Wallen', 99, list([])],
#         ['2022-12-24', 'Major Distribution', 'Drake & 21 Savage', 100,
#          list([])]],
#
#        [['2022-12-31', 'All I Want For Christmas Is You',
#          'Mariah Carey', 1, list([])],
#         ['2022-12-31', "Rockin' Around The Christmas Tree",
#          'Brenda Lee', 2, list([])],
#         ['2022-12-31', 'Jingle Bell Rock', 'Bobby Helms', 3, list([])],
#         ...,
#         ['2022-12-31', 'Hold Me Closer', 'Elton John & Britney Spears',
#          98, list([])],
#         ['2022-12-31', 'Far', 'SZA', 99, list([])],
#         ['2022-12-31', 'All Mine', 'Brent Faiyaz', 100, list([])]]],
#       dtype=object)
# (53, 100, 5)

# %%
songSet = set()
for chart in yearchart:
    for song in chart:
        songSet.add(song[1]+"-"+song[2])

# %%
len(songSet)
# Out:
# 763

# %%
features = ['danceability', 'energy', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']
ls = list(songSet)
trackIDs = []
songdict = {}
def getID(num):
    temp = []
    for i in range(num * 77, num * 77 + 77):
        if i < len(ls) - 1:
            trackID = sp.search(ls[i], limit=1)['tracks']['items'][0]['id']
            temp.append(trackID)
            songdict[trackID] = [ls[i], []]
    trackIDs.append(temp)

getID(0)

# %%
getID(1)

# %%
getID(2)

# %%
getID(3)

# %%
getID(4)

# %%
getID(5)

# %%
getID(6)

# %%
getID(7)

# %%
getID(8)

# %%
getID(9)

# %%
len(trackIDs)
# Out:
# 10

# %%
def getFeatures(num):
    features = sp.audio_features(tracks=trackIDs[num])
    for id, feature in zip(trackIDs[num], features):
        songdict[id] = [songdict[id][0], [feature["danceability"], feature["energy"], feature["loudness"], feature["mode"], feature["speechiness"], feature["acousticness"], feature["instrumentalness"], feature["liveness"], feature["valence"], feature["tempo"]]]

# %%
features = sp.audio_features(tracks=['15npbUjCgwt2lRvyrJvyxw'])
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:934, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     933 try:
# --> 934     retries = retries.increment(method, url, response=response, _pool=self)
#     935 except MaxRetryError:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=15npbUjCgwt2lRvyrJvyxw (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\adapters.py:691, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     690 if isinstance(e.reason, ResponseError):
# --> 691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=15npbUjCgwt2lRvyrJvyxw (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 features = sp.audio_features(tracks=['15npbUjCgwt2lRvyrJvyxw'])
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:1753, in Spotify.audio_features(self, tracks)
#    1751 else:
#    1752     tlist = [self._get_id("track", t) for t in tracks]
# -> 1753     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1754 # the response has changed, look for the new style first, and if
#    1755 # it's not there, fallback on the old style
#    1756 if "audio_features" in results:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:311, in Spotify._internal_call(self, method, url, payload, params)
#     309     except (IndexError, AttributeError):
#     310         reason = None
# --> 311     raise SpotifyException(
#     312         429,
#     313         -1,
#     314         f"{request.path_url}:\n Max Retries",
#     315         reason=reason
#     316     )
#     317 except ValueError:
#     318     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=15npbUjCgwt2lRvyrJvyxw:
#  Max Retries, reason: too many 429 error responses

# %%
getFeatures(9)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\connectionpool.py:934, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     933 try:
# --> 934     retries = retries.increment(method, url, response=response, _pool=self)
#     935 except MaxRetryError:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=15npbUjCgwt2lRvyrJvyxw,3AKwkcaoREu24cKpKwnYj7,6NQchnlpozM5o4n6WfDznd,2BJWxD8xKrDv8vneTvTIm9,2uFaJJtFpPDc5Pa95XzTvg,1B5I5yqLpVI5EosZS6bJFs,6JbrcjoMVBBNZllVOiHBcU,0UmMT7DNXCOJvSmXXGNG5b,59CfNbkERJ3NoTXDvoURjj,6V74LEfuOKN9iz7YinOWpB,7l2nxyx7IkBX5orhkALg0V,46IZ0fSY2mpAiktS3KOqds,221qmpQeBNV87sUjQeUTVH,2lUDBd7JrgAMltcp6dcd7D,0uw91RQRCkpNDP4IqQsL65,2ZlABhxMMa43COmZ97kKsJ,4vb777iaycnlFxVkJMmtfd,7lcI4X8RZxK4zIknJcwpBq,77khP2fIVhSW
vpO1o8SpkdH3txtJQQc7,38xhBO2AKrJnjdjVnhJES6,3qoftcUZaUOncvIYjFSPdE,1PNs0uGru3TcrA94kpyGnc,3tBZ60j1jQ7NJm8IjelyQe,3F5CgOj3wFlRv51JsHbxhe,3Vi5XqYrmQgOYBajMWSvCi,3iHzKA9HlXf5wsGdsrsnSA,1bDbXMyjaUIooNwFE9wn0N,6koKhrBBcExADvWuOgceNZ,02VBYrHfVwfEWXk5DXyf0T,0sn26qH64SDVoKo2Gm7lYV,7GeTsDIc5ykNB6lORO6Cee,0xzI1KAr0Yd9tv8jlIk3sn,0ysCB1Jg4hli0XlEWlipo7,3Wrjm47oTz2sjIgck11l5e,5EDtmgwR1lDmDGLZraNpJg,1oc92BMKYkNxK17C2GtyRM,3kfqYE0jGONOrkVpkPPOd5,4OkFBMU18NidtaefaTjUq1,1eIXYZWEfJO3Na2LCCnIJE,705dwKmZCd7ImAUyyD6Mpm,1T4k0sw0HldDg004Kw4Oct,4zmKGsrXjLmljb5fTaBTot,54bm2e3tk8cliUz3VSdCPZ,4ZUpTMKPYFTfJqamWFU9Zv,7LczcBaamU9pTkV4Cl9NyX,7GARzfC1mwhDuk4t9WOACq,3PBBbN8EiB6A6uZ0xSUuJ6,1SOClUWhOi8vHZYMz3GluK,5Z01UMMf7V1o0MzF86s6WJ,4Dvkj6JhhA12EX05fT7y2e,1dm6z1fWB0cErMszU25dy2,25BIuLc3xxqGyg2kAAiFZ6,52nTQQahs46s1iHFQ3Wv5Q,5ASM6Qjiav2xPe7gRkQMsQ,0wHFktze2PHC5jDt3B17DC,567H4GSoFa1BZjAkngbvBF,3QFInJAm9eyaho5vBzxInN,5jQI2r1RdgtuT8S3iG8zFC,7My9ca9QEIR8MvIOdIrTWA,0mL82sxCRjrs3br407IdJh,36mU1SRz3SFAoiVuHhZ8yj,1AZjCZSGEjlxUufFQwSszF,1TlTzdsEpgfsmbuNfYmWfG,1DnSNqCQM3LUxqFuXt184Q,1Y3LN4zO1Edc2EluIoSPJN,510mvRgE4jLSsJcBh2pH0j,2HZLXBOnaSRhXStMLrq9fD (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 getFeatures(9)
#
# Cell In[91], line 2, in getFeatures(num)
#       1 def getFeatures(num):
# ----> 2     features = sp.audio_features(tracks=trackIDs[num])
#       3     for id, feature in zip(trackIDs[num], features):
#       4         songdict[id] = [songdict[id][0], [feature["danceability"], feature["energy"], feature["loudness"], feature["mode"], feature["speechiness"], feature["acousticness"], feature["instrumentalness"], feature["liveness"], feature["valence"], feature["tempo"]]]
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:1753, in Spotify.audio_features(self, tracks)
#    1751 else:
#    1752     tlist = [self._get_id("track", t) for t in tracks]
# -> 1753     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1754 # the response has changed, look for the new style first, and if
#    1755 # it's not there, fallback on the old style
#    1756 if "audio_features" in results:
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\sungc\CommunityAnalitics\.venv\Lib\site-packages\spotipy\client.py:311, in Spotify._internal_call(self, method, url, payload, params)
#     309     except (IndexError, AttributeError):
#     310         reason = None
# --> 311     raise SpotifyException(
#     312         429,
#     313         -1,
#     314         f"{request.path_url}:\n Max Retries",
#     315         reason=reason
#     316     )
#     317 except ValueError:
#     318     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids